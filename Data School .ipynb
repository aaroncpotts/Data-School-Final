# %%
import pandas as pd

# %%
cf = pd.read_csv("Data\Cafeteria_inspection_data_cleaned.csv")

# %%
#In future revisions adding this smoothly with a proper join is the goal, but for now this is just the 

en = pd.read_csv("Data/2021SchoolYearEnrollmentByBorough.csv")

# %%
cf.describe()
# Out:
#             ZipCode          PTET      LATITUDE     LONGITUDE  COMMUNITYBOARD  \
# count  10942.000000  11093.000000  11093.000000  11093.000000    10942.000000
# mean   10895.816852   2530.937889     40.715508    -73.929995      286.875525
# std      515.710848      1.457172      0.083525      0.078320      107.279709
# min    10001.000000   2529.000000     40.507893    -74.244116      101.000000
# 25%    10455.000000   2530.000000     40.643653    -73.979893      206.000000
# 50%    11207.000000   2530.000000     40.703534    -73.940061      308.000000
# 75%    11231.000000   2533.000000     40.780013    -73.890070      318.000000
# max    11694.000000   2533.000000     40.906892    -73.709136      503.000000
#
#        COUNCILDISTRICT    CENSUSTRACT           BIN           BBL  \
# count     11093.000000   10942.000000  1.088000e+04  1.109300e+04
# mean         27.458127   39160.660939  2.924761e+06  2.772769e+09
# std          14.663363   33574.986465  1.131412e+06  1.140226e+09
# min           1.000000     100.000000  1.000000e+06  1.000000e+00
# 25%          15.000000   15500.000000  2.041260e+06  2.029390e+09
# 50%          31.000000   27300.000000  3.116438e+06  3.032410e+09
# 75%          39.000000   53000.000000  3.398406e+06  3.081880e+09
# max          51.000000  162100.000000  5.170018e+06  5.078980e+09
#
#            BOROCODE
# count  11093.000000
# mean       2.780672
# std        1.076977
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        5.000000

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11093 entries, 0 to 11092
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Record ID             11093 non-null  object
#  1   SchoolName            11093 non-null  object
#  2   Number                11093 non-null  object
#  3   Street                11093 non-null  object
#  4   City                  10657 non-null  object
#  5   State                 11093 non-null  object
#  6   Borough               11093 non-null  object
#  7   ZipCode               10942 non-null  float64
#  8   LastInspection        11093 non-null  object
#  9   Permittee             11093 non-null  object
#  10  InspectionDate        11093 non-null  object
#  11  PTET                  11093 non-null  int64
#  12  Site Type             11093 non-null  object
#  13  Level                 7974 non-null   object
#  14  Code                  7974 non-null   object
#  15  ViolationDescription  7974 non-null   object
#  16  LATITUDE              11093 non-null  float64
#  17  LONGITUDE             11093 non-null  float64
#  18  COMMUNITYBOARD        10942 non-null  float64
#  19  COUNCILDISTRICT       11093 non-null  int64
#  20  CENSUSTRACT           10942 non-null  float64
#  21  BIN                   10880 non-null  float64
#  22  BBL                   11093 non-null  int64
#  23  NTA                   10942 non-null  object
#  24  BOROCODE              11093 non-null  int64
# dtypes: float64(6), int64(4), object(15)
# memory usage: 2.1+ MB

# %%
en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Borough               15 non-null     object
#  1   Schooling Status      15 non-null     object
#  2   2021-2022 Enrollment  15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 488.0+ bytes

# %%
en.head()
# Out:
#     Borough Schooling Status  2021-2022 Enrollment
# 0     Bronx           Public                158295
# 1     Bronx          Private                 23954
# 2     Bronx   Home Schooling                  2284
# 3  Brooklyn           Public                256706
# 4  Brooklyn          Private                116725

# %%
cf.head()
# Out:
#   Record ID                                         SchoolName Number  \
# 0  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    350
# 1  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    350
# 2  40540220                               P.S. 001 TOTTENVILLE     58
# 3  40540220                               P.S. 001 TOTTENVILLE     58
# 4  40540237               SOUTH RICHMOND HS (Bldg 24) PS/IS 25   6581
#
#             Street City State        Borough  ZipCode LastInspection  \
# 0    YETMAN AVENUE  NaN    NY  Staten Island  10307.0     12/21/2022
# 1    YETMAN AVENUE  NaN    NY  Staten Island  10307.0     12/21/2022
# 2    SUMMIT STREET  NaN    NY  Staten Island  10307.0     12/21/2022
# 3    SUMMIT STREET  NaN    NY  Staten Island  10307.0     12/21/2022
# 4  HYLAN BOULEVARD  NaN    NY  Staten Island  10309.0      12/7/2022
#
#                                Permittee  ...  \
# 0  NEW YORK CITY DEPARTMENT OF EDUCATION  ...
# 1  NEW YORK CITY DEPARTMENT OF EDUCATION  ...
# 2  NEW YORK CITY DEPARTMENT OF EDUCATION  ...
# 3  NEW YORK CITY DEPARTMENT OF EDUCATION  ...
# 4  NEW YORK CITY DEPARTMENT OF EDUCATION  ...
#
#                                 ViolationDescription   LATITUDE  LONGITUDE  \
# 0  Non-food contact surface or equipment made of ...  40.507893 -74.242738
# 1                                                NaN  40.507893 -74.242738
# 2  Anti-siphonage or back-flow prevention device ...  40.509029 -74.244116
# 3                                                NaN  40.509029 -74.244116
# 4                                                NaN  40.509077 -74.220928
#
#   COMMUNITYBOARD COUNCILDISTRICT CENSUSTRACT        BIN         BBL   NTA  \
# 0          503.0              51     24401.0  5088090.0  5078940001  SI11
# 1          503.0              51     24401.0  5088090.0  5078940001  SI11
# 2          503.0              51     24401.0  5107854.0  5078980001  SI11
# 3          503.0              51     24401.0  5107854.0  5078980001  SI11
# 4          503.0              51     19800.0  5123970.0  5076640001  SI01
#
#    BOROCODE
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#
# [5 rows x 25 columns]

# %%
cf["Address"] = cf["Number"] + " " + cf["Street"]

# %%
cf.head()
# Out:
#   Record ID                                         SchoolName Number  \
# 0  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    350
# 1  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    350
# 2  40540220                               P.S. 001 TOTTENVILLE     58
# 3  40540220                               P.S. 001 TOTTENVILLE     58
# 4  40540237               SOUTH RICHMOND HS (Bldg 24) PS/IS 25   6581
#
#             Street City State        Borough  ZipCode LastInspection  \
# 0    YETMAN AVENUE  NaN    NY  Staten Island  10307.0     12/21/2022
# 1    YETMAN AVENUE  NaN    NY  Staten Island  10307.0     12/21/2022
# 2    SUMMIT STREET  NaN    NY  Staten Island  10307.0     12/21/2022
# 3    SUMMIT STREET  NaN    NY  Staten Island  10307.0     12/21/2022
# 4  HYLAN BOULEVARD  NaN    NY  Staten Island  10309.0      12/7/2022
#
#                                Permittee  ...   LATITUDE  LONGITUDE  \
# 0  NEW YORK CITY DEPARTMENT OF EDUCATION  ...  40.507893 -74.242738
# 1  NEW YORK CITY DEPARTMENT OF EDUCATION  ...  40.507893 -74.242738
# 2  NEW YORK CITY DEPARTMENT OF EDUCATION  ...  40.509029 -74.244116
# 3  NEW YORK CITY DEPARTMENT OF EDUCATION  ...  40.509029 -74.244116
# 4  NEW YORK CITY DEPARTMENT OF EDUCATION  ...  40.509077 -74.220928
#
#   COMMUNITYBOARD COUNCILDISTRICT CENSUSTRACT        BIN         BBL   NTA  \
# 0          503.0              51     24401.0  5088090.0  5078940001  SI11
# 1          503.0              51     24401.0  5088090.0  5078940001  SI11
# 2          503.0              51     24401.0  5107854.0  5078980001  SI11
# 3          503.0              51     24401.0  5107854.0  5078980001  SI11
# 4          503.0              51     19800.0  5123970.0  5076640001  SI01
#
#    BOROCODE               Address
# 0         5     350 YETMAN AVENUE
# 1         5     350 YETMAN AVENUE
# 2         5      58 SUMMIT STREET
# 3         5      58 SUMMIT STREET
# 4         5  6581 HYLAN BOULEVARD
#
# [5 rows x 26 columns]

# %%
cf.drop(columns=["Number", "Street"])
# Out:
#       Record ID                                         SchoolName   City  \
# 0      40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    NaN
# 1      40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...    NaN
# 2      40540220                               P.S. 001 TOTTENVILLE    NaN
# 3      40540220                               P.S. 001 TOTTENVILLE    NaN
# 4      40540237               SOUTH RICHMOND HS (Bldg 24) PS/IS 25    NaN
# ...         ...                                                ...    ...
# 11088  50117998                    MOSS OUTPOST AT SAR HIGH SCHOOL  Bronx
# 11089  50117998                    MOSS OUTPOST AT SAR HIGH SCHOOL  Bronx
# 11090  50117998                    MOSS OUTPOST AT SAR HIGH SCHOOL  Bronx
# 11091  50117998                    MOSS OUTPOST AT SAR HIGH SCHOOL  Bronx
# 11092  50117998                    MOSS OUTPOST AT SAR HIGH SCHOOL  Bronx
#
#       State        Borough  ZipCode LastInspection  \
# 0        NY  Staten Island  10307.0     12/21/2022
# 1        NY  Staten Island  10307.0     12/21/2022
# 2        NY  Staten Island  10307.0     12/21/2022
# 3        NY  Staten Island  10307.0     12/21/2022
# 4        NY  Staten Island  10309.0      12/7/2022
# ...     ...            ...      ...            ...
# 11088    NY          Bronx  10471.0      3/20/2023
# 11089    NY          Bronx  10471.0      3/20/2023
# 11090    NY          Bronx  10471.0      3/20/2023
# 11091    NY          Bronx  10471.0      3/20/2023
# 11092    NY          Bronx  10471.0      3/20/2023
#
#                                    Permittee InspectionDate  PTET  ...  \
# 0      NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530  ...
# 1      NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530  ...
# 2      NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530  ...
# 3      NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530  ...
# 4      NEW YORK CITY DEPARTMENT OF EDUCATION      1/18/2022  2530  ...
# ...                                      ...            ...   ...  ...
# 11088                          MOSS CAFE LLC      3/20/2023  2529  ...
# 11089                          MOSS CAFE LLC      5/25/2022  2529  ...
# 11090                          MOSS CAFE LLC      5/25/2022  2529  ...
# 11091                          MOSS CAFE LLC      3/20/2023  2529  ...
# 11092                          MOSS CAFE LLC      3/20/2023  2529  ...
#
#         LATITUDE  LONGITUDE COMMUNITYBOARD COUNCILDISTRICT  CENSUSTRACT  \
# 0      40.507893 -74.242738          503.0              51      24401.0
# 1      40.507893 -74.242738          503.0              51      24401.0
# 2      40.509029 -74.244116          503.0              51      24401.0
# 3      40.509029 -74.244116          503.0              51      24401.0
# 4      40.509077 -74.220928          503.0              51      19800.0
# ...          ...        ...            ...             ...          ...
# 11088  40.906892 -73.904271          208.0              11      32300.0
# 11089  40.906892 -73.904271          208.0              11      32300.0
# 11090  40.906892 -73.904271          208.0              11      32300.0
# 11091  40.906892 -73.904271          208.0              11      32300.0
# 11092  40.906892 -73.904271          208.0              11      32300.0
#
#              BIN         BBL   NTA  BOROCODE               Address
# 0      5088090.0  5078940001  SI11         5     350 YETMAN AVENUE
# 1      5088090.0  5078940001  SI11         5     350 YETMAN AVENUE
# 2      5107854.0  5078980001  SI11         5      58 SUMMIT STREET
# 3      5107854.0  5078980001  SI11         5      58 SUMMIT STREET
# 4      5123970.0  5076640001  SI01         5  6581 HYLAN BOULEVARD
# ...          ...         ...   ...       ...                   ...
# 11088  2086339.0  2059570152  BX22         2  503 WEST  259 STREET
# 11089  2086339.0  2059570152  BX22         2  503 WEST  259 STREET
# 11090  2086339.0  2059570152  BX22         2  503 WEST  259 STREET
# 11091  2086339.0  2059570152  BX22         2  503 WEST  259 STREET
# 11092  2086339.0  2059570152  BX22         2  503 WEST  259 STREET
#
# [11093 rows x 24 columns]

# %%
cf = cf.drop(columns=["COMMUNITYBOARD", "CENSUSTRACT", "BBL", "NTA", "BOROCODE", "Number", "Street"])

# %%
cf.head()
# Out:
#   Record ID                                         SchoolName City State  \
# 0  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...  NaN    NY
# 1  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...  NaN    NY
# 2  40540220                               P.S. 001 TOTTENVILLE  NaN    NY
# 3  40540220                               P.S. 001 TOTTENVILLE  NaN    NY
# 4  40540237               SOUTH RICHMOND HS (Bldg 24) PS/IS 25  NaN    NY
#
#          Borough  ZipCode LastInspection  \
# 0  Staten Island  10307.0     12/21/2022
# 1  Staten Island  10307.0     12/21/2022
# 2  Staten Island  10307.0     12/21/2022
# 3  Staten Island  10307.0     12/21/2022
# 4  Staten Island  10309.0      12/7/2022
#
#                                Permittee InspectionDate  PTET  \
# 0  NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530
# 1  NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530
# 2  NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530
# 3  NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530
# 4  NEW YORK CITY DEPARTMENT OF EDUCATION      1/18/2022  2530
#
#                        Site Type Level Code  \
# 0  FSE (Public School Cafeteria)     G  10F
# 1  FSE (Public School Cafeteria)   NaN  NaN
# 2  FSE (Public School Cafeteria)     G  10B
# 3  FSE (Public School Cafeteria)   NaN  NaN
# 4  FSE (Public School Cafeteria)   NaN  NaN
#
#                                 ViolationDescription   LATITUDE  LONGITUDE  \
# 0  Non-food contact surface or equipment made of ...  40.507893 -74.242738
# 1                                                NaN  40.507893 -74.242738
# 2  Anti-siphonage or back-flow prevention device ...  40.509029 -74.244116
# 3                                                NaN  40.509029 -74.244116
# 4                                                NaN  40.509077 -74.220928
#
#    COUNCILDISTRICT        BIN               Address
# 0               51  5088090.0     350 YETMAN AVENUE
# 1               51  5088090.0     350 YETMAN AVENUE
# 2               51  5107854.0      58 SUMMIT STREET
# 3               51  5107854.0      58 SUMMIT STREET
# 4               51  5123970.0  6581 HYLAN BOULEVARD

# %%
cf.insert(19, '2021-2022 Segment Enrollment', 'x')

# %%
# Create  new column "Public Status" with empty values - inserting was not a great call
cf["Public Status"] = ""

# %%
# Loop through the rows of the dataframe in Column "Site Type" to set the public/private type
# Note: Column must be named "Site Type" exactly or the code will very reasonably assume all schools are private. Check column headers and correct as necessary.
for i in range(len(cf)):
  # Check if the column "Site Type" contains "FSE (Public School Cafeteria)"
  if cf.loc[i, "Site Type"] == "FSE (Public School Cafeteria)":
    # Write "Public" in the column "Public Status"
    cf.loc[i, "Public Status"] = "Public"
  else:
    # Write "Private" in the column "Public Status"
    cf.loc[i, "Public Status"] = "Private"

# %%
for row in cf.iterrows():

    # Get the value of the Borough column
    borough = row[1]['Borough']

    # Get the value of the Public Status column
    public_status = row[1]['Public Status']

    # Check if the Borough column contains Brooklyn
    if borough == 'Brooklyn':

        # Check if the Public Status column contains Public
        if public_status == 'Public':

            # Write 513412 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 260855

        else:

            # Write 116725 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 116725
    elif borough == 'Bronx':
         # Check if the Public Status column contains Public
        if public_status == 'Public':

            # Write 513412 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 168582

        else:

            # Write 116725 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 23954
            
    elif borough == 'Queens':
         # Check if the Public Status column contains Public
        if public_status == 'Public':

            # Write 513412 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 263898
        else:

            # Write 116725 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 39686
    elif borough == 'Manhattan':
         # Check if the Public Status column contains Public
        if public_status == 'Public':

            # Write 513412 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 152463
        else:

            # Write 116725 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 49856
    else:
        if public_status == 'Public':

            # Write 513412 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 61797
        else:

            # Write 116725 in the 2021-2022 Segment Enrollment column
            cf.loc[row[0], '2021-2022 Segment Enrollment'] = 11337

# %%
cf.head()
# Out:
#   Record ID                                         SchoolName City State  \
# 0  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...  NaN    NY
# 1  40547725  I.S. 034 TOTTENVILLE, SOUTH RICHMOND HIGH SCHO...  NaN    NY
# 2  40540220                               P.S. 001 TOTTENVILLE  NaN    NY
# 3  40540220                               P.S. 001 TOTTENVILLE  NaN    NY
# 4  40540237               SOUTH RICHMOND HS (Bldg 24) PS/IS 25  NaN    NY
#
#          Borough  ZipCode LastInspection  \
# 0  Staten Island  10307.0     12/21/2022
# 1  Staten Island  10307.0     12/21/2022
# 2  Staten Island  10307.0     12/21/2022
# 3  Staten Island  10307.0     12/21/2022
# 4  Staten Island  10309.0      12/7/2022
#
#                                Permittee InspectionDate  PTET  ... Level Code  \
# 0  NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530  ...     G  10F
# 1  NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530  ...   NaN  NaN
# 2  NEW YORK CITY DEPARTMENT OF EDUCATION     12/21/2022  2530  ...     G  10B
# 3  NEW YORK CITY DEPARTMENT OF EDUCATION      3/10/2022  2530  ...   NaN  NaN
# 4  NEW YORK CITY DEPARTMENT OF EDUCATION      1/18/2022  2530  ...   NaN  NaN
#
#                                 ViolationDescription   LATITUDE  LONGITUDE  \
# 0  Non-food contact surface or equipment made of ...  40.507893 -74.242738
# 1                                                NaN  40.507893 -74.242738
# 2  Anti-siphonage or back-flow prevention device ...  40.509029 -74.244116
# 3                                                NaN  40.509029 -74.244116
# 4                                                NaN  40.509077 -74.220928
#
#    COUNCILDISTRICT        BIN               Address  \
# 0               51  5088090.0     350 YETMAN AVENUE
# 1               51  5088090.0     350 YETMAN AVENUE
# 2               51  5107854.0      58 SUMMIT STREET
# 3               51  5107854.0      58 SUMMIT STREET
# 4               51  5123970.0  6581 HYLAN BOULEVARD
#
#   2021-2022 Segment Enrollment Public Status
# 0                        61797        Public
# 1                        61797        Public
# 2                        61797        Public
# 3                        61797        Public
# 4                        61797        Public
#
# [5 rows x 21 columns]

# %%
#You'll need to manually put this into the Tableau data folder

cf.to_csv("DOHMH Cafeteria Inspections and Segment Enrollment.csv")
